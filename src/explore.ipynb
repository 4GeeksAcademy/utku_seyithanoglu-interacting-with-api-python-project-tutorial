# %% [markdown]
# # Explore here

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
from dotenv import load_dotenv

# load the .env file variables
load_dotenv()
# Out:
# True

# %%
import requests

url = "https://potterapi-fedeperin.vercel.app/en/characters"
response = requests.get(url)
data = response.json()

response.status_code
# Out:
# 200

# %%
print(data)
# Out:
# [{'fullName': 'Harry James Potter', 'nickname': 'Harry', 'hogwartsHouse': 'Gryffindor', 'interpretedBy': 'Daniel Radcliffe', 'children': ['James Sirius Potter', 'Albus Severus Potter', 'Lily Luna Potter'], 'image': 'https://raw.githubusercontent.com/fedeperin/potterapi/main/public/images/characters/harry_potter.png', 'birthdate': 'Jul 31, 1980', 'index': 0}, {'fullName': 'Hermione Jean Granger', 'nickname': 'Hermione', 'hogwartsHouse': 'Gryffindor', 'interpretedBy': 'Emma Watson', 'children': ['Rose Granger-Weasley', 'Hugo Granger-Weasley'], 'image': 'https://raw.githubusercontent.com/fedeperin/potterapi/main/public/images/characters/hermione_granger.png', 'birthdate': 'Sep 19, 1979', 'index': 1}, {'fullName': 'Ron Weasley', 'nickname': 'Ron', 'hogwartsHouse': 'Gryffindor', 'interpretedBy': 'Rupert Grint', 'children': ['Rose Granger-Weasley', 'Hugo Granger-Weasley'], 'image': 'https://raw.githubusercontent.com/fedeperin/potterapi/main/public/images/characters/ron_weasley.png', 'birthdate': 'Mar 1, 1980', 'index': 2}, {'fullName': 'Fred Weasley', 'nickname': 'Fred', 'hogwartsHouse': 'Gryffindor', 'interpretedBy': 'James Phelps', 'children': [], 'image': 'https://raw.githubusercontent.com/fedeperin/potterapi/main/public/images/characters/fred_weasley.png', 'birthdate': 'Apr 1, 1978', 'index': 3}, {'fullName': 'George Weasley', 'nickname': 'George', 'hogwartsHouse': 'Gryffindor', 'interpretedBy': 'Oliver Phelps', 'children': [], 'image': 'https://raw.githubusercontent.com/fedeperin/potterapi/main/public/images/characters/george_weasley.png', 'birthdate': 'Apr 1, 1978', 'index': 4}, {'fullName': 'Bill Weasley', 'nickname': 'Bill', 'hogwartsHouse': 'Gryffindor', 'interpretedBy': 'Domhnall Gleeson', 'children': [], 'image': 'https://raw.githubusercontent.com/fedeperin/potterapi/main/public/images/characters/bill_weasley.png', 'birthdate': 'Nov 29, 1970', 'index': 5}, {'fullName': 'Percy Weasley', 'nickname': 'Percy', 'hogwartsHouse': 'Gryffindor', 'interpretedBy': 'Chris Rankin', 'children': [], 'image': 'https://raw.githubusercontent.com/fedeperin/potterapi/main/public/images/characters/percy_weasley.png', 'birthdate': 'Aug 22, 1976', 'index': 6}, {'fullName': 'Charlie Weasley', 'nickname': 'Charlie', 'hogwartsHouse': 'Gryffindor', 'interpretedBy': '', 'children': [], 'image': 'https://raw.githubusercontent.com/fedeperin/potterapi/main/public/images/characters/charlie_weasley.png', 'birthdate': 'Dec 12, 1972', 'index': 7}, {'fullName': 'Ginny Weasley', 'nickname': 'Ginny', 'hogwartsHouse': 'Gryffindor', 'interpretedBy': 'Bonnie Right', 'children': ['James Sirius Potter', 'Albus Severus Potter', 'Lily Luna Potter'], 'image': 'https://raw.githubusercontent.com/fedeperin/potterapi/main/public/images/characters/ginny_weasley.png', 'birthdate': 'Aug 11, 1981', 'index': 8}, {'fullName': 'Molly Weasley', 'nickname': 'Molly', 'hogwartsHouse': 'Gryffindor', 'interpretedBy': 'Julie Walters', 'children': ['Ron Weasley', 'Fred Weasley', 'George Weasley', 'Bill Weasley', 'Percy Weasley', 'Charlie Weasley', 'Ginny Weasley'], 'image': 'https://raw.githubusercontent.com/fedeperin/potterapi/main/public/images/characters/molly_weasley.png', 'birthdate': 'Oct 30, 1949', 'index': 9}, {'fullName': 'Arthur Weasley', 'nickname': 'Arthur', 'hogwartsHouse': 'Gryffindor', 'interpretedBy': 'Mark Williams', 'children': ['Ron Weasley', 'Fred Weasley', 'George Weasley', 'Bill Weasley', 'Percy Weasley', 'Charlie Weasley', 'Ginny Weasley'], 'image': 'https://raw.githubusercontent.com/fedeperin/potterapi/main/public/images/characters/arthur_weasley.png', 'birthdate': 'Feb 6, 1950', 'index': 10}, {'fullName': 'Neville Longbottom', 'nickname': 'Neville', 'hogwartsHouse': 'Gryffindor', 'interpretedBy': 'Matthew Lewis', 'children': [], 'image': 'https://raw.githubusercontent.com/fedeperin/potterapi/main/public/images/characters/neville_longbottom.png', 'birthdate': 'Jul 30, 1980', 'index': 11}, {'fullName': 'Luna Lovegood', 'nickname': 'Luna', 'hogwartsHouse': 'Ravenc ...

# %%
data[0].keys()
# Out:
# dict_keys(['fullName', 'nickname', 'hogwartsHouse', 'interpretedBy', 'children', 'image', 'birthdate', 'index'])

# %%
data[0].values()
# Out:
# dict_values(['Harry James Potter', 'Harry', 'Gryffindor', 'Daniel Radcliffe', ['James Sirius Potter', 'Albus Severus Potter', 'Lily Luna Potter'], 'https://raw.githubusercontent.com/fedeperin/potterapi/main/public/images/characters/harry_potter.png', 'Jul 31, 1980', 0])

# %%
data[1].keys()
# Out:
# dict_keys(['fullName', 'nickname', 'hogwartsHouse', 'interpretedBy', 'children', 'image', 'birthdate', 'index'])

# %%
data[0]['interpretedBy']
# Out:
# 'Daniel Radcliffe'

# %%
data[0]['hogwartsHouse']
# Out:
# 'Gryffindor'

# %%
house = []
for i in range(len(data)):
     house.append(data[i]['hogwartsHouse'])

# %%
house
# Out:
# ['Gryffindor',
#  'Gryffindor',
#  'Gryffindor',
#  'Gryffindor',
#  'Gryffindor',
#  'Gryffindor',
#  'Gryffindor',
#  'Gryffindor',
#  'Gryffindor',
#  'Gryffindor',
#  'Gryffindor',
#  'Gryffindor',
#  'Ravenclaw',
#  'Slytherin',
#  'Gryffindor',
#  'Gryffindor',
#  'Gryffindor',
#  'Gryffindor',
#  'Gryffindor',
#  'Slytherin',
#  'Slytherin',
#  'Slytherin',
#  'Hufflepuff',
#  'Hufflepuff',
#  'Gryffindor']

# %%
for i in range(len(data)):
    print(data[i]['fullName'])
# Out:
# Harry James Potter
# Hermione Jean Granger
# Ron Weasley
# Fred Weasley
# George Weasley
# Bill Weasley
# Percy Weasley
# Charlie Weasley
# Ginny Weasley
# Molly Weasley
# Arthur Weasley
# Neville Longbottom
# Luna Lovegood
# Draco Malfoy
# Albus Percival Wulfric Brian Dumbledore
# Minerva McGonagall
# Remus Lupin
# Rubeus Hagrid
# Sirius Black
# Severus Snape
# Bellatrix Lestrange
# Lord Voldemort
# Cedric Diggory
# Nymphadora Tonks
# James Potter

# %%
for i in range(len(data)):
    print(data[i]['nickname'])
    print(data[i]['fullName'])
# Out:
# Harry
# Harry James Potter
# Hermione
# Hermione Jean Granger
# Ron
# Ron Weasley
# Fred
# Fred Weasley
# George
# George Weasley
# Bill
# Bill Weasley
# Percy
# Percy Weasley
# Charlie
# Charlie Weasley
# Ginny
# Ginny Weasley
# Molly
# Molly Weasley
# Arthur
# Arthur Weasley
# Neville
# Neville Longbottom
# Luna
# Luna Lovegood
# Draco
# Draco Malfoy
# Dumbledore
# Albus Percival Wulfric Brian Dumbledore
# Minerva
# Minerva McGonagall
# Lupin
# Remus Lupin
# Hagrid
# Rubeus Hagrid
# Sirius
# Sirius Black
# Snape
# Severus Snape
# Bella
# Bellatrix Lestrange
# Voldemort
# Lord Voldemort
# Cedric
# Cedric Diggory
# Tonks
# Nymphadora Tonks
# James
# James Potter

# %%
import pandas as pd

print(pd.DataFrame(data).head())
# Out:
#                 fullName  nickname hogwartsHouse     interpretedBy  \
# 0     Harry James Potter     Harry    Gryffindor  Daniel Radcliffe
# 1  Hermione Jean Granger  Hermione    Gryffindor       Emma Watson
# 2            Ron Weasley       Ron    Gryffindor      Rupert Grint
# 3           Fred Weasley      Fred    Gryffindor      James Phelps
# 4         George Weasley    George    Gryffindor     Oliver Phelps
#
#                                             children  \
# 0  [James Sirius Potter, Albus Severus Potter, Li...
# 1       [Rose Granger-Weasley, Hugo Granger-Weasley]
# 2       [Rose Granger-Weasley, Hugo Granger-Weasley]
# 3                                                 []
# 4                                                 []
#
#                                                image     birthdate  index
# 0  https://raw.githubusercontent.com/fedeperin/po...  Jul 31, 1980      0
# 1  https://raw.githubusercontent.com/fedeperin/po...  Sep 19, 1979      1
# 2  https://raw.githubusercontent.com/fedeperin/po...   Mar 1, 1980      2
# 3  https://raw.githubusercontent.com/fedeperin/po...   Apr 1, 1978      3
# 4  https://raw.githubusercontent.com/fedeperin/po...   Apr 1, 1978      4

# %%
print(type(data))
# Out:
# <class 'list'>

# %%
print(data[0]['fullName'])
print(data[0]['birthdate'])
# Out:
# Harry James Potter
# Jul 31, 1980

# %%
data[1]['nickname']
# Out:
# 'Hermione'

# %%
a = 0

for i in range(len(data)):
    nickname = data[i].get("nickname")

    if nickname:   # dolu string ise
        print(data[i]["fullName"], "-> nickname var")
    else:
        print(data[i]["fullName"], "-> nickname YOK")
        a += 1

print("Nickname olmayan kişi sayısı:", a)
# Out:
# Harry James Potter -> nickname var
# Hermione Jean Granger -> nickname var
# Ron Weasley -> nickname var
# Fred Weasley -> nickname var
# George Weasley -> nickname var
# Bill Weasley -> nickname var
# Percy Weasley -> nickname var
# Charlie Weasley -> nickname var
# Ginny Weasley -> nickname var
# Molly Weasley -> nickname var
# Arthur Weasley -> nickname var
# Neville Longbottom -> nickname var
# Luna Lovegood -> nickname var
# Draco Malfoy -> nickname var
# Albus Percival Wulfric Brian Dumbledore -> nickname var
# Minerva McGonagall -> nickname var
# Remus Lupin -> nickname var
# Rubeus Hagrid -> nickname var
# Sirius Black -> nickname var
# Severus Snape -> nickname var
# Bellatrix Lestrange -> nickname var
# Lord Voldemort -> nickname var
# Cedric Diggory -> nickname var
# Nymphadora Tonks -> nickname var
# James Potter -> nickname var
# Nickname olmayan kişi sayısı: 0

# %%
a = 0
for i in range(len(data)):
    nickname = data[i].get("nickname")

    if nickname :
        print(data[i]["nickname"])
    else:
        a+=1
        print(f"Number of people without nicknames :{a}")
# Out:
# Harry
# Hermione
# Ron
# Fred
# George
# Bill
# Percy
# Charlie
# Ginny
# Molly
# Arthur
# Neville
# Luna
# Draco
# Dumbledore
# Minerva
# Lupin
# Hagrid
# Sirius
# Snape
# Bella
# Voldemort
# Cedric
# Tonks
# James

# %%
a=0
for i in range(len(data)):
    images = data[i].get("image")
    if images :
        pass
        #print(data[i]["image"])
    else:
        a+=1
        # print(f"Number of people without nicknames :{a}")
        print(a)

# %%
a=0
for i in range(len(data)):
    images = data[i].get("image")
    if images :
        
        print(data[i]["image"])
    else:
        a+=1
        # print(f"Number of people without nicknames :{a}")
        print(a)
# Out:
# https://raw.githubusercontent.com/fedeperin/potterapi/main/public/images/characters/harry_potter.png
# https://raw.githubusercontent.com/fedeperin/potterapi/main/public/images/characters/hermione_granger.png
# https://raw.githubusercontent.com/fedeperin/potterapi/main/public/images/characters/ron_weasley.png
# https://raw.githubusercontent.com/fedeperin/potterapi/main/public/images/characters/fred_weasley.png
# https://raw.githubusercontent.com/fedeperin/potterapi/main/public/images/characters/george_weasley.png
# https://raw.githubusercontent.com/fedeperin/potterapi/main/public/images/characters/bill_weasley.png
# https://raw.githubusercontent.com/fedeperin/potterapi/main/public/images/characters/percy_weasley.png
# https://raw.githubusercontent.com/fedeperin/potterapi/main/public/images/characters/charlie_weasley.png
# https://raw.githubusercontent.com/fedeperin/potterapi/main/public/images/characters/ginny_weasley.png
# https://raw.githubusercontent.com/fedeperin/potterapi/main/public/images/characters/molly_weasley.png
# https://raw.githubusercontent.com/fedeperin/potterapi/main/public/images/characters/arthur_weasley.png
# https://raw.githubusercontent.com/fedeperin/potterapi/main/public/images/characters/neville_longbottom.png
# https://raw.githubusercontent.com/fedeperin/potterapi/main/public/images/characters/luna_lovegood.png
# https://raw.githubusercontent.com/fedeperin/potterapi/main/public/images/characters/draco_malfoy.png
# https://raw.githubusercontent.com/fedeperin/potterapi/main/public/images/characters/albus_dumbledore.png
# https://raw.githubusercontent.com/fedeperin/potterapi/main/public/images/characters/minerva_mcgonagall.png
# https://raw.githubusercontent.com/fedeperin/potterapi/main/public/images/characters/remus_lupin.png
# https://raw.githubusercontent.com/fedeperin/potterapi/main/public/images/characters/rubeus_hagrid.png
# https://raw.githubusercontent.com/fedeperin/potterapi/main/public/images/characters/sirius_black.png
# https://raw.githubusercontent.com/fedeperin/potterapi/main/public/images/characters/severus_snape.png
# https://raw.githubusercontent.com/fedeperin/potterapi/main/public/images/characters/bellatrix_lestrange.png
# https://raw.githubusercontent.com/fedeperin/potterapi/main/public/images/characters/lord_voldemort.png
# https://raw.githubusercontent.com/fedeperin/potterapi/main/public/images/characters/cedric_diggory.png
# https://raw.githubusercontent.com/fedeperin/potterapi/main/public/images/characters/nymphadora_tonks.png
# https://raw.githubusercontent.com/fedeperin/potterapi/main/public/images/characters/james_potter.png

# %%
birtday_name = []
for i in range(len(data)):
    birtday_name.append(data[i]['birthdate'])

# %%
birtday_name
# Out:
# ['Jul 31, 1980',
#  'Sep 19, 1979',
#  'Mar 1, 1980',
#  'Apr 1, 1978',
#  'Apr 1, 1978',
#  'Nov 29, 1970',
#  'Aug 22, 1976',
#  'Dec 12, 1972',
#  'Aug 11, 1981',
#  'Oct 30, 1949',
#  'Feb 6, 1950',
#  'Jul 30, 1980',
#  'Feb 13, 1981',
#  'Jun 5, 1980',
#  'Aug 29, 1881',
#  'Oct 4, 1935',
#  'Mar 10, 1960',
#  'Dec 6, 1928',
#  'Nov 3, 1959',
#  'Jan 9, 1960',
#  'Dec 13, 1951',
#  'Dec 31, 1926',
#  'Sep 29, 1977',
#  'Dec 25, 1972',
#  'Mar 27, 1960']

# %%
name=[]
for i in range(len(data)):
    name.append(data[i]['nickname'])

# %%
import pandas as pd

# %%
birtday=pd.DataFrame(birtday_name)

# %%
name = pd.DataFrame(name)

# %%
name
# Out:
#              0
# 0        Harry
# 1     Hermione
# 2          Ron
# 3         Fred
# 4       George
# 5         Bill
# 6        Percy
# 7      Charlie
# 8        Ginny
# 9        Molly
# 10      Arthur
# 11     Neville
# 12        Luna
# 13       Draco
# 14  Dumbledore
# 15     Minerva
# 16       Lupin
# 17      Hagrid
# 18      Sirius
# 19       Snape
# 20       Bella
# 21   Voldemort
# 22      Cedric
# 23       Tonks
# 24       James

# %%
time_df=pd.concat([birtday,name],axis=1)

# %%
time_df
# Out:
#                0           0
# 0   Jul 31, 1980       Harry
# 1   Sep 19, 1979    Hermione
# 2    Mar 1, 1980         Ron
# 3    Apr 1, 1978        Fred
# 4    Apr 1, 1978      George
# 5   Nov 29, 1970        Bill
# 6   Aug 22, 1976       Percy
# 7   Dec 12, 1972     Charlie
# 8   Aug 11, 1981       Ginny
# 9   Oct 30, 1949       Molly
# 10   Feb 6, 1950      Arthur
# 11  Jul 30, 1980     Neville
# 12  Feb 13, 1981        Luna
# 13   Jun 5, 1980       Draco
# 14  Aug 29, 1881  Dumbledore
# 15   Oct 4, 1935     Minerva
# 16  Mar 10, 1960       Lupin
# 17   Dec 6, 1928      Hagrid
# 18   Nov 3, 1959      Sirius
# 19   Jan 9, 1960       Snape
# 20  Dec 13, 1951       Bella
# 21  Dec 31, 1926   Voldemort
# 22  Sep 29, 1977      Cedric
# 23  Dec 25, 1972       Tonks
# 24  Mar 27, 1960       James

# %%
time_df.columns = ["birthdate", "name"]

# %%
time_df
# Out:
#        birthdate        name
# 0   Jul 31, 1980       Harry
# 1   Sep 19, 1979    Hermione
# 2    Mar 1, 1980         Ron
# 3    Apr 1, 1978        Fred
# 4    Apr 1, 1978      George
# 5   Nov 29, 1970        Bill
# 6   Aug 22, 1976       Percy
# 7   Dec 12, 1972     Charlie
# 8   Aug 11, 1981       Ginny
# 9   Oct 30, 1949       Molly
# 10   Feb 6, 1950      Arthur
# 11  Jul 30, 1980     Neville
# 12  Feb 13, 1981        Luna
# 13   Jun 5, 1980       Draco
# 14  Aug 29, 1881  Dumbledore
# 15   Oct 4, 1935     Minerva
# 16  Mar 10, 1960       Lupin
# 17   Dec 6, 1928      Hagrid
# 18   Nov 3, 1959      Sirius
# 19   Jan 9, 1960       Snape
# 20  Dec 13, 1951       Bella
# 21  Dec 31, 1926   Voldemort
# 22  Sep 29, 1977      Cedric
# 23  Dec 25, 1972       Tonks
# 24  Mar 27, 1960       James

# %%
time_df['house']=house

# %%
time_df
# Out:
#        birthdate        name       house
# 0   Jul 31, 1980       Harry  Gryffindor
# 1   Sep 19, 1979    Hermione  Gryffindor
# 2    Mar 1, 1980         Ron  Gryffindor
# 3    Apr 1, 1978        Fred  Gryffindor
# 4    Apr 1, 1978      George  Gryffindor
# 5   Nov 29, 1970        Bill  Gryffindor
# 6   Aug 22, 1976       Percy  Gryffindor
# 7   Dec 12, 1972     Charlie  Gryffindor
# 8   Aug 11, 1981       Ginny  Gryffindor
# 9   Oct 30, 1949       Molly  Gryffindor
# 10   Feb 6, 1950      Arthur  Gryffindor
# 11  Jul 30, 1980     Neville  Gryffindor
# 12  Feb 13, 1981        Luna   Ravenclaw
# 13   Jun 5, 1980       Draco   Slytherin
# 14  Aug 29, 1881  Dumbledore  Gryffindor
# 15   Oct 4, 1935     Minerva  Gryffindor
# 16  Mar 10, 1960       Lupin  Gryffindor
# 17   Dec 6, 1928      Hagrid  Gryffindor
# 18   Nov 3, 1959      Sirius  Gryffindor
# 19   Jan 9, 1960       Snape   Slytherin
# 20  Dec 13, 1951       Bella   Slytherin
# 21  Dec 31, 1926   Voldemort   Slytherin
# 22  Sep 29, 1977      Cedric  Hufflepuff
# 23  Dec 25, 1972       Tonks  Hufflepuff
# 24  Mar 27, 1960       James  Gryffindor

# %%
time_df['birthdate']=pd.to_datetime(time_df['birthdate'])

# %%
time_df.head()
# Out:
#    birthdate      name       house
# 0 1980-07-31     Harry  Gryffindor
# 1 1979-09-19  Hermione  Gryffindor
# 2 1980-03-01       Ron  Gryffindor
# 3 1978-04-01      Fred  Gryffindor
# 4 1978-04-01    George  Gryffindor

# %%
time_df=time_df.sort_values(by='birthdate',ascending = False)

# %%
time_df
# Out:
#     birthdate        name       house
# 8  1981-08-11       Ginny  Gryffindor
# 12 1981-02-13        Luna   Ravenclaw
# 0  1980-07-31       Harry  Gryffindor
# 11 1980-07-30     Neville  Gryffindor
# 13 1980-06-05       Draco   Slytherin
# 2  1980-03-01         Ron  Gryffindor
# 1  1979-09-19    Hermione  Gryffindor
# 3  1978-04-01        Fred  Gryffindor
# 4  1978-04-01      George  Gryffindor
# 22 1977-09-29      Cedric  Hufflepuff
# 6  1976-08-22       Percy  Gryffindor
# 23 1972-12-25       Tonks  Hufflepuff
# 7  1972-12-12     Charlie  Gryffindor
# 5  1970-11-29        Bill  Gryffindor
# 24 1960-03-27       James  Gryffindor
# 16 1960-03-10       Lupin  Gryffindor
# 19 1960-01-09       Snape   Slytherin
# 18 1959-11-03      Sirius  Gryffindor
# 20 1951-12-13       Bella   Slytherin
# 10 1950-02-06      Arthur  Gryffindor
# 9  1949-10-30       Molly  Gryffindor
# 15 1935-10-04     Minerva  Gryffindor
# 17 1928-12-06      Hagrid  Gryffindor
# 21 1926-12-31   Voldemort   Slytherin
# 14 1881-08-29  Dumbledore  Gryffindor

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.Figure(figsize=(9,9)) 
sns.scatterplot(data= time_df,x='name',y='birthdate')
plt.grid()
plt.xticks(rotation=90)
plt.title("age for every carachter")
# Out:
# Text(0.5, 1.0, 'age for every carachter')

# %%
time_df['house'].value_counts()
# Out:
# house
# Gryffindor    18
# Slytherin      4
# Hufflepuff     2
# Ravenclaw      1
# Name: count, dtype: int64

# %%
plt.Figure(figsize=(12,4))
sns.countplot(data=time_df,x='house')
# Out:
# <Axes: xlabel='house', ylabel='count'>
